# %% [markdown]
# # Mathematics Question Text Classification with Support Vector Machine (SVM)

# %% [markdown]
# ## Load Dataset

# %%
#Load dataset from Google Drive
import pandas as pd
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
df = pd.read_csv('/content/drive/MyDrive/Dataset/Matematika-SD-SMP.csv')
df.head()
# Out:
# Mounted at /content/drive
#    NO                                    id  \
# 0   1  8e4cb4de-bf0c-49ba-87bb-fed51419d294
# 1   2  80ed6b49-0e35-4677-978a-a551523d2aaf
# 2   3  1fe60e13-2323-4d5a-bfab-a004a23abd88
# 3   4  a0235e0f-8a6b-42f8-95eb-d8be56a8517b
# 4   5  5604840d-4e0f-4194-90b4-e8e89161eca1
#
#                                             question  \
# 0  Seseorang mempunyai sejumlah uang yang akan di...
# 1  Rumus jumlah n suku pertama deret aritmetika a...
# 2  Bakteri jenis A berkembang biak menjadi dua ka...
# 3  Seorang ayah membagikan uang sebesar Rp 100.00...
# 4  Suatu perusahaan pakaian dapat menghasilkan 4....
#
#                                              choices key  \
# 0  A. Rp6.750.000,00\n B. Rp7.050.000,00\n C. Rp7...   B
# 1  A. 39\n                                       ...   E
# 2  A.  640Â Â Â Â \n\t\t\t\t\t\t\t B.  6.400\n\t\...   B
# 3  A. Rp     15.000,00Â Â Â Â \n                 ...   C
# 4  A. 45.500 Â Â Â Â \n\t\t\t\t\t\t\t B.  50.500Â...   E
#
#                            key_text label_1   indikator label_2
# 0                  Rp7.050.000,00\n      C3  mengaitkan  sedang
# 1                                87      C3  menghitung   mudah
# 2             6.400\n\t\t\t\t\t\t\t      C3  menghitung   sulit
# 3  Rp     17.500,00\n\t\t\t\t\t\t\t      C3  menghitung   sulit
# 4                            51.300      C3  menghitung  sedang

# %% [markdown]
# ## Preprocessing Data

# %%
import re
import string

#Removing character
def hapus_karakter_selain_huruf(text):
  for sp in string.punctuation:
    text = text.replace(sp, " ")
  text = re.sub(r"\d+","",text)    
  return text.replace('/\s\s+/g', ' ')

df['question'] = df['question'].apply(hapus_karakter_selain_huruf)
df.head()
# Out:
#    NO                                    id  \
# 0   1  8e4cb4de-bf0c-49ba-87bb-fed51419d294
# 1   2  80ed6b49-0e35-4677-978a-a551523d2aaf
# 2   3  1fe60e13-2323-4d5a-bfab-a004a23abd88
# 3   4  a0235e0f-8a6b-42f8-95eb-d8be56a8517b
# 4   5  5604840d-4e0f-4194-90b4-e8e89161eca1
#
#                                             question  \
# 0  Seseorang mempunyai sejumlah uang yang akan di...
# 1  Rumus jumlah n suku pertama deret aritmetika a...
# 2  Bakteri jenis A berkembang biak menjadi dua ka...
# 3  Seorang ayah membagikan uang sebesar Rp    kep...
# 4  Suatu perusahaan pakaian dapat menghasilkan   ...
#
#                                              choices key  \
# 0  A. Rp6.750.000,00\n B. Rp7.050.000,00\n C. Rp7...   B
# 1  A. 39\n                                       ...   E
# 2  A.  640Â Â Â Â \n\t\t\t\t\t\t\t B.  6.400\n\t\...   B
# 3  A. Rp     15.000,00Â Â Â Â \n                 ...   C
# 4  A. 45.500 Â Â Â Â \n\t\t\t\t\t\t\t B.  50.500Â...   E
#
#                            key_text label_1   indikator label_2
# 0                  Rp7.050.000,00\n      C3  mengaitkan  sedang
# 1                                87      C3  menghitung   mudah
# 2             6.400\n\t\t\t\t\t\t\t      C3  menghitung   sulit
# 3  Rp     17.500,00\n\t\t\t\t\t\t\t      C3  menghitung   sulit
# 4                            51.300      C3  menghitung  sedang

# %%
#Stopwords array
sw = ["aja", "agan", "barang", "beli", "baru", "ada",
      "adalah", "ajaa", "akan", "aku", "atas",
      "buat", "boss", "agak", "agar", "apa",
      "biar", "bsa", "alhmdulillah", "alhamdulilah", "akhir",
      "allah", "ane", "arn", "atau", "audah", 
      "bang", "aaaa", "about", "adik", "ah",
      "admin", "and", "as", "bakalan", "barank", "amin",
      "begini","begitu","beberapa"]

#Removing stopword
def stopwords(text):
  text = [word.lower() for word in text.split()] #casefolding
  for word in text:
    for stop in sw:
      if word==stop:
        text.remove(word)
  text = " ".join(text)
  text = re.sub(r'(.+?)\1+', r'\1',text)
  return text

df['question'] = df['question'].apply(stopwords)
df.head()
# Out:
#    NO                                    id  \
# 0   1  8e4cb4de-bf0c-49ba-87bb-fed51419d294
# 1   2  80ed6b49-0e35-4677-978a-a551523d2aaf
# 2   3  1fe60e13-2323-4d5a-bfab-a004a23abd88
# 3   4  a0235e0f-8a6b-42f8-95eb-d8be56a8517b
# 4   5  5604840d-4e0f-4194-90b4-e8e89161eca1
#
#                                             question  \
# 0  seorang mempunyai sejumlah uang yang diambil t...
# 1  rumus jumlah n suku pertama deret aritmetika s...
# 2  bakteri jenis a berkembang biak menjadi dua ka...
# 3  seorang ayah membagikan uang sebesar rp kepada...
# 4  suatu perusahan pakaian dapat menghasilkan bua...
#
#                                              choices key  \
# 0  A. Rp6.750.000,00\n B. Rp7.050.000,00\n C. Rp7...   B
# 1  A. 39\n                                       ...   E
# 2  A.  640Â Â Â Â \n\t\t\t\t\t\t\t B.  6.400\n\t\...   B
# 3  A. Rp     15.000,00Â Â Â Â \n                 ...   C
# 4  A. 45.500 Â Â Â Â \n\t\t\t\t\t\t\t B.  50.500Â...   E
#
#                            key_text label_1   indikator label_2
# 0                  Rp7.050.000,00\n      C3  mengaitkan  sedang
# 1                                87      C3  menghitung   mudah
# 2             6.400\n\t\t\t\t\t\t\t      C3  menghitung   sulit
# 3  Rp     17.500,00\n\t\t\t\t\t\t\t      C3  menghitung   sulit
# 4                            51.300      C3  menghitung  sedang

# %%
import sys
# !{sys.executable} -m pip install Sastrawi
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

#Build stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

#Stemming
def stemming(text):
  text = [stemmer.stem(word) for word in text.split()]
  return " ".join(text)
    
df['question'] = df['question'].apply(stemming)
df.head()
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: Sastrawi in /usr/local/lib/python3.9/dist-packages (1.0.1)
#    NO                                    id  \
# 0   1  8e4cb4de-bf0c-49ba-87bb-fed51419d294
# 1   2  80ed6b49-0e35-4677-978a-a551523d2aaf
# 2   3  1fe60e13-2323-4d5a-bfab-a004a23abd88
# 3   4  a0235e0f-8a6b-42f8-95eb-d8be56a8517b
# 4   5  5604840d-4e0f-4194-90b4-e8e89161eca1
#
#                                             question  \
# 0  orang punya jumlah uang yang ambil tiap bulan ...
# 1  rumus jumlah n suku pertama deret aritmetika s...
# 2  bakteri jenis a kembang biak jadi dua kali lip...
# 3  orang ayah bagi uang besar rp kepada orang ana...
# 4  suatu usah pakai dapat hasil buah pada awal pr...
#
#                                              choices key  \
# 0  A. Rp6.750.000,00\n B. Rp7.050.000,00\n C. Rp7...   B
# 1  A. 39\n                                       ...   E
# 2  A.  640Â Â Â Â \n\t\t\t\t\t\t\t B.  6.400\n\t\...   B
# 3  A. Rp     15.000,00Â Â Â Â \n                 ...   C
# 4  A. 45.500 Â Â Â Â \n\t\t\t\t\t\t\t B.  50.500Â...   E
#
#                            key_text label_1   indikator label_2
# 0                  Rp7.050.000,00\n      C3  mengaitkan  sedang
# 1                                87      C3  menghitung   mudah
# 2             6.400\n\t\t\t\t\t\t\t      C3  menghitung   sulit
# 3  Rp     17.500,00\n\t\t\t\t\t\t\t      C3  menghitung   sulit
# 4                            51.300      C3  menghitung  sedang

# %%
#Removing unused columns
df_drop = df.drop(labels=['NO', 'id', 'choices', 'key', 'key_text', 'label_1', 'indikator'], axis=1)
df_drop.head()
# Out:
#                                             question label_2
# 0  orang punya jumlah uang yang ambil tiap bulan ...  sedang
# 1  rumus jumlah n suku pertama deret aritmetika s...   mudah
# 2  bakteri jenis a kembang biak jadi dua kali lip...   sulit
# 3  orang ayah bagi uang besar rp kepada orang ana...   sulit
# 4  suatu usah pakai dapat hasil buah pada awal pr...  sedang

# %% [markdown]
# ## Splitting Dataset

# %%
from sklearn import model_selection
train_x, test_x, train_y, test_y = model_selection.train_test_split(df['question'],df['label_2'],test_size=0.2, random_state=13)

# %% [markdown]
# ## Feature Extractions

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer

# %%
#TF-IDF
TFIDF_vect = TfidfVectorizer(max_features=5000)
TFIDF_vect.fit(df_drop['question'])
train_x_tfidf = TFIDF_vect.transform(train_x)
test_x_tfidf = TFIDF_vect.transform(test_x)
print(TFIDF_vect.vocabulary_)
# Out:
# {'orang': 441, 'punya': 504, 'jumlah': 257, 'uang': 657, 'yang': 684, 'ambil': 22, 'tiap': 633, 'bulan': 118, 'besar': 94, 'ikut': 226, 'atur': 41, 'baris': 65, 'aritmetika': 34, 'pada': 444, 'pertama': 479, 'rp': 525, 'dua': 168, 'tiga': 636, 'demikian': 149, 'terus': 629, 'seluruh': 563, 'telah': 614, 'lama': 337, 'rumus': 530, 'suku': 595, 'deret': 152, 'tujuh': 649, 'dari': 141, 'sebut': 547, 'bakteri': 57, 'jenis': 253, 'kembang': 292, 'biak': 96, 'jadi': 238, 'kali': 265, 'lipat': 360, 'lima': 355, 'menit': 399, 'waktu': 679, 'belas': 78, 'banyak': 64, 'puluh': 502, 'ayah': 44, 'bagi': 49, 'kepada': 299, 'anak': 24, 'makin': 376, 'muda': 416, 'usia': 674, 'kecil': 281, 'terima': 626, 'jika': 255, 'selisih': 562, 'oleh': 438, 'dekat': 146, 'dan': 139, 'si': 573, 'sulung': 596, 'paling': 453, 'maka': 374, 'bungsu': 122, 'suatu': 591, 'usah': 672, 'pakai': 450, 'dapat': 140, 'hasil': 210, 'buah': 113, 'awal': 43, 'produksi': 498, 'tingkat': 640, 'bila': 100, 'maju': 373, 'tetap': 631, 'dalam': 138, 'tahun': 601, 'ruang': 526, 'tunjuk': 652, 'milik': 405, 'kursi': 329, 'di': 154, 'kempat': 293, 'tahu': 600, 'saudara': 546, 'dengan': 150, 'umur': 665, 'sama': 536, 'tua': 646, 'mereka': 400, 'kenam': 296, 'geometri': 195, 'positif': 490, 'turut': 655, 'rasio': 515, 'itu': 236, 'ke': 279, 'log': 363, 'populasi': 489, 'seranga': 570, 'sat': 543, 'ini': 230, 'capai': 126, 'ekor': 173, 'datang': 143, 'nilai': 427, 'bilang': 101, 'bentuk': 85, 'tambah': 604, 
 'kubik': 323, 'akar': 13, 'kuadrat': 322, 'kpk': 320, 'ialah': 222, 'fpb': 184, 'prima': 497, 'suhu': 594, 'air': 11, 'masuk': 386, 'frezer': 185, 'kemudian': 294, 'alami': 15, 'turun': 654, 'es': 179, 'sekarang': 556, 'samping': 539, 'mingu': 406, 'sapu': 541, 'tangan': 609, 'mana': 378, 'rupa': 531, 'ciri': 129, 'belah': 75, 'ketupat': 305, 'satu': 545, 'ibu': 224, 'beli': 79, 'sarden': 542, 'kaleng': 264, 'exp': 180, 'date': 145, 'baik': 52, 'konsumsi': 316, 'buat': 114, 'kue': 325, 'bolu': 105, 'gulung': 200, 'potong': 491, 'delapan': 148, 'jarum': 248, 'pendek': 468, 'angka': 25, 'gelas': 190, 'beri': 92, 'sudah': 592, 'cair': 125, 'naik': 421, 'lagi': 331, 'kulkas': 326, 'sedang': 548, 'bedan': 72, 'udara': 660, 'dingin': 160, 'mula': 417, 'untuk': 667, 'ubah': 658, 'segar': 550, 'beku': 74, 'harus': 209, 'puncak': 503, 'gung': 202, 'matahari': 388, 'terbit': 624, 'energi': 178, 'panas': 454, 'jam': 242, 'jarak': 244, 'kota': 318, 'bandung': 60, 'jakarta': 240, 'km': 311, 'skala': 584, 'peta': 481, 'ruas': 527, 'garis': 187, 'adalah': 4, 'lebih': 348, 'kurang': 328, 'kerucut': 303, 'kelipat': 286, 'sekutu': 559, 'terang': 623, 'perlu': 473, 'kena': 295, 'adan': 5, 'segi': 551, 'rumah': 529, 'abid': 2, 'seko': 557, 'hm': 219, 'kebun': 280, 'kakek': 261, 'pagar': 447, 'biaya': 98, 'per': 471, 'pasang': 460, 'jaran': 245, 'genjang': 193, 'asli': 39, 'cxlix': 134, 'tingi': 639, 'mcmxci': 394, 'marbun': 381, 'uras': 670, 'bakmandi': 56, 'bak': 54, 'mandi': 379, 'kak': 260, 'windu': 681, 'pak': 449, 'edo': 171, 'cat': 127, 'merlukan': 401, 'semua': 566, 'r ...

# %% [markdown]
# ## SVM Model

# %%
from sklearn import naive_bayes
from sklearn.metrics import classification_report

# %%
# SVM dengan TF-IDF Vectorizer

MNB_TFIDF = naive_bayes.MultinomialNB()
MNB_TFIDF.fit(train_x_tfidf ,train_y)
predictions_MNB_TFIDF = MNB_TFIDF.predict(test_x_tfidf)
print(classification_report(test_y, predictions_MNB_TFIDF))
# Out:
#               precision    recall  f1-score   support
#
#        mudah       0.88      0.33      0.48        21
#       sedang       0.57      0.97      0.72        35
#        sulit       0.00      0.00      0.00        12
#
#     accuracy                           0.60        68
#    macro avg       0.48      0.43      0.40        68
# weighted avg       0.56      0.60      0.52        68
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# SVM dengan Count Vectorizer

MNB_BoW = naive_bayes.MultinomialNB()
MNB_BoW.fit(train_x_count,train_y)
predictions_MNB_BoW = MNB_BoW.predict(test_x_count)
print(classification_report(test_y, predictions_MNB_BoW))
# Out:
#               precision    recall  f1-score   support
#
#        mudah       0.75      0.71      0.73        21
#       sedang       0.71      0.83      0.76        35
#        sulit       0.71      0.42      0.53        12
#
#     accuracy                           0.72        68
#    macro avg       0.72      0.65      0.67        68
# weighted avg       0.72      0.72      0.71        68
